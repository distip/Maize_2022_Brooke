# %%
import pandas as pd
import numpy as np

# %%
#reading greenhouse multispew data
data_greenhouse = pd.read_csv("Multispeq_HIPS_GS1_GH.csv")

# %%
#reading field multispeq data
data_field = pd.read_csv("Multispeq_HIPS_GS1_Field.csv")

# %%
data_greenhouse.head()
# Out:
#         ID          Series  Repeat  PLOT ID  REP  air_temp_kinetics  \
# 0  2826053  Whole Data Set       1     4104    2   27.78,27.79,27.8
# 1  2826043  Whole Data Set       1     4104    1  27.82,27.82,27.82
# 2  2826052  Whole Data Set       1     4106    2  27.86,27.87,27.87
# 3  2826042  Whole Data Set       1     4106    1   27.9,27.91,27.92
# 4  2826065  Whole Data Set       1     4108    2  27.25,27.26,27.28
#
#    Ambient Humidity  Ambient Pressure  Ambient Temperature  \
# 0          41.63965         975.71924                27.80
# 1          42.10254         975.71295                27.82
# 2          41.73926         975.76263                27.87
# 3          42.39844         975.74005                27.92
# 4          42.12012         975.98578                27.28
#
#                                         data_raw_PAM  ...                time  \
# 0  460,458,458,458,458,458,457,457,457,457,456,45...  ...  06/29/2022 4:04 PM
# 1  456,453,455,453,454,454,453,456,454,456,458,45...  ...  06/29/2022 4:20 PM
# 2  290,288,290,286,288,289,287,288,289,290,289,29...  ...  06/29/2022 4:05 PM
# 3  406,407,409,407,406,408,408,408,407,406,406,40...  ...  06/29/2022 4:21 PM
# 4  472,471,470,469,470,469,471,471,470,471,468,46...  ...  06/29/2022 3:46 PM
#
#    Time of Day   tP700 v_initial_P700    vH+              User    Device ID  \
# 0    16.074722  0.0017       0.011985  0.005  Deniz Istipliler  52:00:08:06
# 1    16.341944  0.0106       0.007547  0.009  Deniz Istipliler  52:00:08:06
# 2    16.086389 -0.0031       0.006549  0.000  Deniz Istipliler  52:00:08:06
# 3    16.357222  0.0103       0.008763  0.003  Deniz Istipliler  52:00:08:06
# 4    15.773611  0.0046       0.008741  0.009  Deniz Istipliler  52:00:08:06
#
#     Latitude  Longitude Issues
# 0  40.832821 -96.690845    NaN
# 1  40.832800 -96.690827    NaN
# 2  40.832824 -96.690848    NaN
# 3  40.832817 -96.690844    NaN
# 4  40.832815 -96.690846    NaN
#
# [5 rows x 59 columns]

# %%
#Inserting the column "Source" with the value of 'GH'
data_greenhouse.insert(4, "Source", np.repeat("GH", 213))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-7648c0eeaae3> in <module>()
# ----> 1 data_greenhouse.insert(4, "Source", np.repeat("GH", 213))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3626         self._ensure_valid_index(value)
#    3627         value = self._sanitize_column(column, value, broadcast=False)
# -> 3628         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3629
#    3630     def assign(self, **kwargs) -> "DataFrame":
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1184         if not allow_duplicates and item in self.items:
#    1185             # Should this be a different kind of error??
# -> 1186             raise ValueError(f"cannot insert {item}, already exists")
#    1187
#    1188         if not isinstance(loc, int):
#
# ValueError: cannot insert Source, already exists

# %%
data_greenhouse.head()
# Out:
#         ID          Series  Repeat  PLOT ID Source  REP  air_temp_kinetics  \
# 0  2826053  Whole Data Set       1     4104     GH    2   27.78,27.79,27.8
# 1  2826043  Whole Data Set       1     4104     GH    1  27.82,27.82,27.82
# 2  2826052  Whole Data Set       1     4106     GH    2  27.86,27.87,27.87
# 3  2826042  Whole Data Set       1     4106     GH    1   27.9,27.91,27.92
# 4  2826065  Whole Data Set       1     4108     GH    2  27.25,27.26,27.28
#
#    Ambient Humidity  Ambient Pressure  Ambient Temperature  ...  \
# 0          41.63965         975.71924                27.80  ...
# 1          42.10254         975.71295                27.82  ...
# 2          41.73926         975.76263                27.87  ...
# 3          42.39844         975.74005                27.92  ...
# 4          42.12012         975.98578                27.28  ...
#
#                  time Time of Day   tP700  v_initial_P700    vH+  \
# 0  06/29/2022 4:04 PM   16.074722  0.0017        0.011985  0.005
# 1  06/29/2022 4:20 PM   16.341944  0.0106        0.007547  0.009
# 2  06/29/2022 4:05 PM   16.086389 -0.0031        0.006549  0.000
# 3  06/29/2022 4:21 PM   16.357222  0.0103        0.008763  0.003
# 4  06/29/2022 3:46 PM   15.773611  0.0046        0.008741  0.009
#
#                User    Device ID   Latitude  Longitude  Issues
# 0  Deniz Istipliler  52:00:08:06  40.832821 -96.690845     NaN
# 1  Deniz Istipliler  52:00:08:06  40.832800 -96.690827     NaN
# 2  Deniz Istipliler  52:00:08:06  40.832824 -96.690848     NaN
# 3  Deniz Istipliler  52:00:08:06  40.832817 -96.690844     NaN
# 4  Deniz Istipliler  52:00:08:06  40.832815 -96.690846     NaN
#
# [5 rows x 60 columns]

# %%
data_field.head()
# Out:
#         ID          Series  Repeat  PLOT ID  REP  air_temp_kinetics  \
# 0  2822255  Whole Data Set       1     4104    1  24.44,24.47,24.51
# 1  2822254  Whole Data Set       1     4104    2  24.93,24.97,24.99
# 2  2822253  Whole Data Set       1     4106    1  25.19,25.23,25.24
# 3  2822252  Whole Data Set       1     4106    2  25.35,25.38,25.42
# 4  2822251  Whole Data Set       1     4108    1  25.64,25.66,25.69
#
#    Ambient Humidity  Ambient Pressure  Ambient Temperature  \
# 0          45.55762         980.98608                24.51
# 1          46.45410         980.91498                24.99
# 2          45.39258         980.81995                25.24
# 3          44.93066         980.78674                25.42
# 4          43.59570         980.77661                25.69
#
#                                         data_raw_PAM  ...                time  \
# 0  374,376,375,376,376,376,374,375,377,374,374,37...  ...  06/28/2022 8:18 AM
# 1  404,401,404,400,405,405,401,404,405,405,406,40...  ...  06/28/2022 8:20 AM
# 2  760,756,756,759,758,757,758,754,756,757,756,75...  ...  06/28/2022 8:21 AM
# 3  502,502,500,498,500,501,501,497,498,498,500,50...  ...  06/28/2022 8:21 AM
# 4  436,435,436,436,438,434,436,436,439,438,438,43...  ...  06/28/2022 8:22 AM
#
#    Time of Day   tP700 v_initial_P700    vH+              User    Device ID  \
# 0     8.314722 -0.0001      -0.540479 -0.446  Deniz Istipliler  52:00:08:06
# 1     8.338333 -0.0797      -0.000251  0.040  Deniz Istipliler  52:00:08:06
# 2     8.354444  0.0112       0.164864  0.136  Deniz Istipliler  52:00:08:06
# 3     8.364722  0.0321       0.006851  0.056  Deniz Istipliler  52:00:08:06
# 4     8.380000 -0.0322      -0.000933  0.056  Deniz Istipliler  52:00:08:06
#
#     Latitude  Longitude Issues
# 0  40.852332 -96.616715    NaN
# 1  40.852328 -96.616726    NaN
# 2  40.852266 -96.616658    NaN
# 3  40.852273 -96.616687    NaN
# 4  40.852392 -96.616628    NaN
#
# [5 rows x 59 columns]

# %%
data_field.shape
# Out:
# (217, 59)

# %%
# Looking for the bad measurement acording to multispeq
data_field.loc[data_field["PLOT ID"] == 4236, :]
# Out:
#          ID          Series  Repeat  PLOT ID  REP  air_temp_kinetics  \
# 48  2822207  Whole Data Set       1     4236    1  29.24,29.25,29.27
# 49  2822206  Whole Data Set       1     4236    2  29.32,29.33,29.35
#
#     Ambient Humidity  Ambient Pressure  Ambient Temperature  \
# 48          37.83203         980.59204                29.27
# 49          37.61914         980.59564                29.35
#
#                                          data_raw_PAM  ...  \
# 48  309,309,310,310,307,306,309,314,306,311,311,31...  ...
# 49  248,247,252,246,246,249,250,246,249,248,248,24...  ...
#
#                   time  Time of Day   tP700 v_initial_P700    vH+  \
# 48  06/28/2022 9:05 AM     9.093333  0.0003       0.111131  0.027
# 49  06/28/2022 9:06 AM     9.101667 -0.0036      -0.005541  0.106
#
#                 User    Device ID   Latitude  Longitude Issues
# 48  Deniz Istipliler  52:00:08:06  40.852215 -96.616311    1.0
# 49  Deniz Istipliler  52:00:08:06  40.852199 -96.616309    NaN
#
# [2 rows x 59 columns]

# %%
# dropping the bad measurement (plot id 4236)
data_field = data_field.drop(216)

# %%
#Inserting the column "Source" with the value of "field"
data_field.insert(4, "Source", np.repeat("field", 216))

# %%
data_field.head()
# Out:
#         ID          Series  Repeat  PLOT ID Source  REP  air_temp_kinetics  \
# 0  2822255  Whole Data Set       1     4104  field    1  24.44,24.47,24.51
# 1  2822254  Whole Data Set       1     4104  field    2  24.93,24.97,24.99
# 2  2822253  Whole Data Set       1     4106  field    1  25.19,25.23,25.24
# 3  2822252  Whole Data Set       1     4106  field    2  25.35,25.38,25.42
# 4  2822251  Whole Data Set       1     4108  field    1  25.64,25.66,25.69
#
#    Ambient Humidity  Ambient Pressure  Ambient Temperature  ...  \
# 0          45.55762         980.98608                24.51  ...
# 1          46.45410         980.91498                24.99  ...
# 2          45.39258         980.81995                25.24  ...
# 3          44.93066         980.78674                25.42  ...
# 4          43.59570         980.77661                25.69  ...
#
#                  time Time of Day   tP700  v_initial_P700    vH+  \
# 0  06/28/2022 8:18 AM    8.314722 -0.0001       -0.540479 -0.446
# 1  06/28/2022 8:20 AM    8.338333 -0.0797       -0.000251  0.040
# 2  06/28/2022 8:21 AM    8.354444  0.0112        0.164864  0.136
# 3  06/28/2022 8:21 AM    8.364722  0.0321        0.006851  0.056
# 4  06/28/2022 8:22 AM    8.380000 -0.0322       -0.000933  0.056
#
#                User    Device ID   Latitude  Longitude  Issues
# 0  Deniz Istipliler  52:00:08:06  40.852332 -96.616715     NaN
# 1  Deniz Istipliler  52:00:08:06  40.852328 -96.616726     NaN
# 2  Deniz Istipliler  52:00:08:06  40.852266 -96.616658     NaN
# 3  Deniz Istipliler  52:00:08:06  40.852273 -96.616687     NaN
# 4  Deniz Istipliler  52:00:08:06  40.852392 -96.616628     NaN
#
# [5 rows x 60 columns]

# %%
# Merging two dataframes
merged_data = pd.merge(data_field , data_greenhouse , how= 'outer')

# %%
merged_data.head()
# Out:
#         ID          Series  Repeat  PLOT ID Source  REP  air_temp_kinetics  \
# 0  2822255  Whole Data Set       1     4104  field    1  24.44,24.47,24.51
# 1  2822254  Whole Data Set       1     4104  field    2  24.93,24.97,24.99
# 2  2822253  Whole Data Set       1     4106  field    1  25.19,25.23,25.24
# 3  2822252  Whole Data Set       1     4106  field    2  25.35,25.38,25.42
# 4  2822251  Whole Data Set       1     4108  field    1  25.64,25.66,25.69
#
#    Ambient Humidity  Ambient Pressure  Ambient Temperature  ...  \
# 0          45.55762         980.98608                24.51  ...
# 1          46.45410         980.91498                24.99  ...
# 2          45.39258         980.81995                25.24  ...
# 3          44.93066         980.78674                25.42  ...
# 4          43.59570         980.77661                25.69  ...
#
#                  time Time of Day   tP700  v_initial_P700    vH+  \
# 0  06/28/2022 8:18 AM    8.314722 -0.0001       -0.540479 -0.446
# 1  06/28/2022 8:20 AM    8.338333 -0.0797       -0.000251  0.040
# 2  06/28/2022 8:21 AM    8.354444  0.0112        0.164864  0.136
# 3  06/28/2022 8:21 AM    8.364722  0.0321        0.006851  0.056
# 4  06/28/2022 8:22 AM    8.380000 -0.0322       -0.000933  0.056
#
#                User    Device ID   Latitude  Longitude  Issues
# 0  Deniz Istipliler  52:00:08:06  40.852332 -96.616715     NaN
# 1  Deniz Istipliler  52:00:08:06  40.852328 -96.616726     NaN
# 2  Deniz Istipliler  52:00:08:06  40.852266 -96.616658     NaN
# 3  Deniz Istipliler  52:00:08:06  40.852273 -96.616687     NaN
# 4  Deniz Istipliler  52:00:08:06  40.852392 -96.616628     NaN
#
# [5 rows x 60 columns]

# %%
merged_data.loc[merged_data['PLOT ID'] == 4104 , :]
# Out:
#           ID          Series  Repeat  PLOT ID Source  REP  air_temp_kinetics  \
# 0    2822255  Whole Data Set       1     4104  field    1  24.44,24.47,24.51
# 1    2822254  Whole Data Set       1     4104  field    2  24.93,24.97,24.99
# 216  2826053  Whole Data Set       1     4104     GH    2   27.78,27.79,27.8
# 217  2826043  Whole Data Set       1     4104     GH    1  27.82,27.82,27.82
#
#      Ambient Humidity  Ambient Pressure  Ambient Temperature  ...  \
# 0            45.55762         980.98608                24.51  ...
# 1            46.45410         980.91498                24.99  ...
# 216          41.63965         975.71924                27.80  ...
# 217          42.10254         975.71295                27.82  ...
#
#                    time Time of Day   tP700  v_initial_P700    vH+  \
# 0    06/28/2022 8:18 AM    8.314722 -0.0001       -0.540479 -0.446
# 1    06/28/2022 8:20 AM    8.338333 -0.0797       -0.000251  0.040
# 216  06/29/2022 4:04 PM   16.074722  0.0017        0.011985  0.005
# 217  06/29/2022 4:20 PM   16.341944  0.0106        0.007547  0.009
#
#                  User    Device ID   Latitude  Longitude  Issues
# 0    Deniz Istipliler  52:00:08:06  40.852332 -96.616715     NaN
# 1    Deniz Istipliler  52:00:08:06  40.852328 -96.616726     NaN
# 216  Deniz Istipliler  52:00:08:06  40.832821 -96.690845     NaN
# 217  Deniz Istipliler  52:00:08:06  40.832800 -96.690827     NaN
#
# [4 rows x 60 columns]

# %%
merged_data.shape
# Out:
# (429, 60)

# %%
#save the file as a csv
merged_data.to_csv('GS1_multispeq.csv')

# %%
#reading the ground truth data 
data_ground_truth = pd.read_csv('2022-Brooke-Maize_groundtruth.csv')

# %%
data_ground_truth.head()
# Out:
#   Genotype   PLOT ID  REP  Fresh Weight  Leaf Area  SPAD 1  SPAD 2   SPAD 3  \
# 0      B14A     1028    1          6.55      240.0    46.5     40.7    49.0
# 1      B14A     1028    2          7.90      237.9    40.9     45.3    50.6
# 2     2FACC     1052    1          8.70      273.3    49.2     50.4    52.1
# 3     2FACC     1052    2          6.80      234.6    51.7     49.5    52.3
# 4     PHZ51     1056    1          4.45      178.2    32.6     39.0    35.5
#
#   Field Location  Growth Stage Source
# 0            SAM             1     GH
# 1            SAM             1     GH
# 2            SAM             1     GH
# 3            SAM             1     GH
# 4            SAM             1     GH

# %%
#merging the ground truths with the multispeqs 
## sicti bu burdan devam et
merged_data_with_gt = pd.merge(data_ground_truth, merged_data, how='outer')

# %%
merged_data_with_gt.shape
# Out:
# (500, 68)
