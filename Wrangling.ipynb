# %%
import pandas as pd
import numpy as np

# %%
data =  pd.read_csv('GS1_all_merged.csv')

# %%
data.shape
# Out:
# (1486, 2190)

# %%
data.head(100)
# Out:
#     Unnamed: 0  PLOT ID      Genotype  Rep  Plant Number  Leaf_pos Trt  \
# 0            0     4104  PHJ40 x LH82    1             1       1.0  LN
# 1            1     4104  PHJ40 x LH82    1             1       2.0  LN
# 2            2     4104  PHJ40 x LH82    1             1       3.0  LN
# 3            3     4104  PHJ40 x LH82    1             1       1.0  LN
# 4            4     4104  PHJ40 x LH82    1             1       2.0  LN
# ..         ...      ...           ...  ...           ...       ...  ..
# 95          95     4127     WF9 x H95    1             1       2.0  LN
# 96          96     4127     WF9 x H95    1             1       3.0  LN
# 97          97     4127     WF9 x H95    1             1       1.0  LN
# 98          98     4127     WF9 x H95    1             1       2.0  LN
# 99          99     4127     WF9 x H95    1             1       3.0  LN
#
#     Growth Stage Field Location Source  ...    2491      2492      2493  \
# ...

# %%
# Looking at column names
data.columns[0:50]
# Out:
# Index(['Unnamed: 0', 'PLOT ID', 'Genotype', 'Rep', 'Plant Number', 'Leaf_pos',
#        'Trt', 'Growth Stage', 'Field Location', 'Source', 'Ambient Humidity',
#        'Ambient Pressure', 'Ambient Temperature', 'FmPrime', 'FoPrime', 'Fs',
#        'FvP_over_FmP', 'Leaf Temperature', 'Leaf Temperature Differential',
#        'leaf_thickness', 'LEF', 'NPQt', 'Phi2', 'PhiNO', 'PhiNPQ',
#        'PS1 Active Centers', 'PS1 Open Centers', 'PS1 Over Reduced Centers',
#        'PS1 Oxidized Centers', 'qL', 'SPAD', 'time', 'vH+', 'Genotype.1',
#        'Fresh Weight', 'Leaf Area', 'SPAD 1', 'SPAD 2', 'SPAD 3', '350', '351',
#        '352', '353', '354', '355', '356', '357', '358', '359', '360'],
#       dtype='object')

# %%
data['Field Location'] = data['Field Location'].astype('category')

# %%
data['Field Location'].value_counts()
# Out:
# HIPS    1282
# SAM      204
# Name: Field Location, dtype: int64

# %%
#Group the data by leaf_pos
data = data.groupby(['Field Location','Source','PLOT ID','Genotype','Rep','Plant Number','Trt']).mean()

# %%
data.tail(100)
# Out:
#                                                                   Unnamed: 0  \
# Field Location Source PLOT ID Genotype      Rep Plant Number Trt
# HIPS           field  5216    B37 x Mo17    2   1            MN        688.0
#                                                 2            MN        694.0
#                       5220    F42 x OH43    2   1            MN        700.0
#                                                 2            MN        706.0
#                       5227    PHZ51 x LH145 2   1            MN        712.0
# ...                                                                      ...
#                       6272    F42 x OH43    2   2            HN       1250.0
#                       6274    B37 x H95     2   1            HN       1256.0
#                                                 2            HN       1262.0
#                       6276    PHZ51 x LH145 2   1            HN       1268.0
# ...

# %%
data.shape
# Out:
# (431, 2181)

# %%
#Reset the index 
data=data.reset_index()

# %%
data.head(100)
# Out:
#    Field Location Source  PLOT ID       Genotype  Rep  Plant Number Trt  \
# 0            HIPS     GH     4104   PHJ40 x LH82    1             1  LN
# 1            HIPS     GH     4104   PHJ40 x LH82    1             2  LN
# 2            HIPS     GH     4106  2FACC x 3IIH6    1             1  LN
# 3            HIPS     GH     4106  2FACC x 3IIH6    1             2  LN
# 4            HIPS     GH     4108     B37 x OH43    1             1  LN
# ..            ...    ...      ...            ...  ...           ...  ..
# 95           HIPS     GH     5153     B37 x Mo17    1             2  MN
# 96           HIPS     GH     5154    B73 x 3IIH6    1             1  MN
# 97           HIPS     GH     5154    B73 x 3IIH6    1             2  MN
# 98           HIPS     GH     5160     F42 x OH43    1             1  MN
# 99           HIPS     GH     5160     F42 x OH43    1             2  MN
#
#     Unnamed: 0  Leaf_pos  Growth Stage  ...      2491      2492      2493  \
# ...

# %%
data.shape
# Out:
# (431, 2188)

# %%
data['Field Location'].value_counts()
# Out:
# HIPS    431
# Name: Field Location, dtype: int64

# %%
data.columns[0:30]
# Out:
# Index(['Source', 'Field Location', 'PLOT ID', 'Genotype', 'Rep',
#        'Plant Number', 'Trt', 'Growth Stage', 'Ambient Humidity',
#        'Ambient Pressure', 'Ambient Temperature', 'FmPrime', 'FoPrime', 'Fs',
#        'FvP_over_FmP', 'Leaf Temperature', 'Leaf Temperature Differential',
#        'leaf_thickness', 'LEF', 'NPQt', 'Phi2', 'PhiNO', 'PhiNPQ',
#        'PS1 Active Centers', 'PS1 Open Centers', 'PS1 Over Reduced Centers',
#        'PS1 Oxidized Centers', 'qL', 'SPAD', 'vH+'],
#       dtype='object')

# %%
data.shape
# Out:
# (431, 2188)

# %%
#Remove the unnecessary row 'Unnamed: 0'

data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Remove the Leaf_pos column since we already got the average of it
data.drop('Leaf_pos', axis=1 , inplace=True)

# %%
data.head()
# Out:
#   Source Field Location  PLOT ID       Genotype  Rep  Plant Number Trt  \
# 0     GH           HIPS     4104   PHJ40 x LH82    1             1  LN
# 1     GH           HIPS     4104   PHJ40 x LH82    1             2  LN
# 2     GH           HIPS     4106  2FACC x 3IIH6    1             1  LN
# 3     GH           HIPS     4106  2FACC x 3IIH6    1             2  LN
# 4     GH           HIPS     4108     B37 x OH43    1             1  LN
#
#    Growth Stage  Ambient Humidity  Ambient Pressure  ...      2491      2492  \
# 0           1.0          42.10254         975.71295  ...  0.062700  0.062171
# 1           1.0          41.63965         975.71924  ...  0.072433  0.072067
# 2           1.0          42.39844         975.74005  ...  0.054533  0.054333
# 3           1.0          41.73926         975.76263  ...  0.067867  0.067467
# 4           1.0          40.40137         975.88733  ...  0.061733  0.061533
#
#        2493      2494      2495      2496      2497      2498      2499  \
# ...

# %%
# Taking the three SPAD measurement average and inserting as a new column
data.insert(8, 'SPADmeter', data[['SPAD 1', 'SPAD 2', 'SPAD 3']].mean(axis=1))

# %%
data.head()
# Out:
#   Source Field Location  PLOT ID       Genotype  Rep  Plant Number Trt  \
# 0     GH           HIPS     4104   PHJ40 x LH82    1             1  LN
# 1     GH           HIPS     4104   PHJ40 x LH82    1             2  LN
# 2     GH           HIPS     4106  2FACC x 3IIH6    1             1  LN
# 3     GH           HIPS     4106  2FACC x 3IIH6    1             2  LN
# 4     GH           HIPS     4108     B37 x OH43    1             1  LN
#
#    Growth Stage  SPADmeter  Ambient Humidity  ...      2491      2492  \
# 0           1.0  43.566667          42.10254  ...  0.062700  0.062171
# 1           1.0  49.500000          41.63965  ...  0.072433  0.072067
# 2           1.0  51.533333          42.39844  ...  0.054533  0.054333
# 3           1.0  57.600000          41.73926  ...  0.067867  0.067467
# 4           1.0  54.500000          40.40137  ...  0.061733  0.061533
#
#        2493      2494      2495      2496      2497      2498      2499  \
# ...

# %%
# remove the spad 1 spad 2 and spad 3 since we got their mean
data.drop(['SPAD 1', 'SPAD 2', 'SPAD 3'], axis=1, inplace=True)

# %%
# There is another SPAD in the columns coming from multispeq we will change its name as 'SPAD_multispeq'
data.columns[0:40]
# Out:
# Index(['Source', 'Field Location', 'PLOT ID', 'Genotype', 'Rep',
#        'Plant Number', 'Trt', 'Growth Stage', 'SPADmeter', 'Ambient Humidity',
#        'Ambient Pressure', 'Ambient Temperature', 'FmPrime', 'FoPrime', 'Fs',
#        'FvP_over_FmP', 'Leaf Temperature', 'Leaf Temperature Differential',
#        'leaf_thickness', 'LEF', 'NPQt', 'Phi2', 'PhiNO', 'PhiNPQ',
#        'PS1 Active Centers', 'PS1 Open Centers', 'PS1 Over Reduced Centers',
#        'PS1 Oxidized Centers', 'qL', 'SPAD', 'vH+', 'Fresh Weight',
#        'Leaf Area', '350', '351', '352', '353', '354', '355', '356'],
#       dtype='object')

# %%
#Changing the name of SPAD
data.rename(columns={'SPAD' : 'SPAD_multispeq'}, inplace=True)

# %%
# Check the column names 
data.columns[0:40]
# Out:
# Index(['Source', 'Field Location', 'PLOT ID', 'Genotype', 'Rep',
#        'Plant Number', 'Trt', 'Growth Stage', 'SPADmeter', 'Ambient Humidity',
#        'Ambient Pressure', 'Ambient Temperature', 'FmPrime', 'FoPrime', 'Fs',
#        'FvP_over_FmP', 'Leaf Temperature', 'Leaf Temperature Differential',
#        'leaf_thickness', 'LEF', 'NPQt', 'Phi2', 'PhiNO', 'PhiNPQ',
#        'PS1 Active Centers', 'PS1 Open Centers', 'PS1 Over Reduced Centers',
#        'PS1 Oxidized Centers', 'qL', 'SPAD_multispeq', 'vH+', 'Fresh Weight',
#        'Leaf Area', '350', '351', '352', '353', '354', '355', '356'],
#       dtype='object')

# %%
data.to_csv('GS1_ready_for_analysis.csv')

# %%
data['Field Location'].value_counts()
# Out:
# HIPS    431
# Name: Field Location, dtype: int64

# %% [markdown]
# # DATA IS READY. LET'S DO SOME MACHINE LEARNING. HURRAY!
